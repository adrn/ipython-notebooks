# %%
from matplotlib import ticker

# %%
X,Y = np.meshgrid(np.linspace(0,10,100), np.linspace(0,10,100))

# %%
Z = X**2 + Y**2

# %%
cs = contourf(X, Y, Z, locator=ticker.LogLocator())
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1064bafc8>

# %%
cs = contourf(X, Y, Z, levels=np.logspace(-3,3,10))
