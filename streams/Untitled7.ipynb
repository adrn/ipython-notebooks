# %%
import astropy.units as u
from astropy.constants import G
from streams.misc import UnitSystem
from streams.dynamics import ParticleCollection, OrbitCollection

# %%
from streams.io.lm10 import *

# %%
particles_today(N=1)
# Out:
# kpc {u'length': Unit("kpc"), u'mass': Unit("solMass"), u'time': Unit("Gyr")}
# <ParticleCollection N=1>

# %% [markdown]
# ----

# %%
from streams.io.sgr import *

# %%
for m in ['2.5e{0}'.format(exp) for exp in range(6,10)]:
    s = satellite_today(m)
    p = particles_today(m, N=1000)
    figure(figsize=(5,5))
    plot(p._r[:,0], p._r[:,2], marker='.', alpha=0.5, linestyle='none')
    xlim(-100, 100)
    ylim(-100, 100)
